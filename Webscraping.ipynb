# %%
import urllib.request
from bs4 import BeautifulSoup

# %%
user_input = input('What would you like to search')
url_to_scrape = f'https://www.goodreads.com/search?utf8=%E2%9C%93&query={user_input}'
# Out:
# What would you like to search

# %%
request_page = urllib.request.urlopen(url_to_scrape)
page_html = request_page.read()
request_page.close()

# %%
html_soup = BeautifulSoup(page_html, 'html.parser')

# %%
print(html_soup)
# Out:
# <!DOCTYPE html>
#
# <html class="desktop">
# <head>
# <title>Search results for "" (showing 1-0 of 0 books)</title>
# <meta content="telephone=no" name="format-detection"/>
# <meta content="noindex" name="robots"/>
# <script type="text/javascript"> var ue_t0=window.ue_t0||+new Date();
#  </script>
# <script type="text/javascript">
#     var ue_mid = "A1PQBFHBHS6YH1";
#     var ue_sn = "www.goodreads.com";
#     var ue_furl = "fls-na.amazon.com";
#     var ue_sid = "326-4604061-2969859";
#     var ue_id = "FWKWZP2G5P39H7M6N32N";
#
# ...

# %%
book_titles = html_soup.find_all('a', class_='bookTitle')

# %%
book_author = html_soup.find_all('a', class_='authorName')
#book_author

# %%
book_rating = html_soup.find_all('span',class_='minirating')

# %%
filename = 'goodreadsBooks.csv'

# %%
books_file=open(filename,'w')

# %%
headers = 'Book Title, Book Author, Book Rating \n'
f.write(headers)
# Out:
# 38

# %%
for i in range(len(book_titles)):
               title = book_titles[i].text.replace(',', '')
               author = book_author[i].text
               rating = book_rating[i].text
#               print(title,author,rating)
               books_file.write(title + ',' + author +',' + rating)
               books_file.to_csv(filename)
